# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Housing.csv")

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.describe(include = ["object"])
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
df["mainroad"].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df_sorted = df.sort_values(by="area",ascending=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df_sorted.head()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 449  3150000  1650         3          1        2       no        no      yes
# 537  1890000  1700         3          1        2      yes        no       no
# 527  2275000  1836         2          1        1       no        no      yes
# 271  4340000  1905         5          1        2       no        no      yes
# 413  3430000  1950         3          2        2      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 449              no              no        0       no      unfurnished
# 537              no              no        0       no      unfurnished
# 527              no              no        0       no   semi-furnished
# 271              no              no        0       no   semi-furnished
# 413              no              no        0      yes      unfurnished

# %%
df["price"].mean()
# Out:
# 4766729.247706422

# %%
df["area"].mean()
# Out:
# 5150.54128440367

# %%
df["furnishingstatus"].value_counts()
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
df[ df["bathrooms"] == 1 ].describe()
# Out:
#               price          area    bedrooms  bathrooms     stories  \
# count  4.010000e+02    401.000000  401.000000      401.0  401.000000
# mean   4.206913e+06   4920.892768    2.802993        1.0    1.630923
# std    1.432609e+06   2140.726015    0.684537        0.0    0.733786
# min    1.750000e+06   1650.000000    1.000000        1.0    1.000000
# 25%    3.234000e+06   3500.000000    2.000000        1.0    1.000000
# 50%    3.990000e+06   4320.000000    3.000000        1.0    2.000000
# 75%    4.900000e+06   6000.000000    3.000000        1.0    2.000000
# max    1.141000e+07  15600.000000    6.000000        1.0    4.000000
#
#           parking
# count  401.000000
# mean     0.610973
# std      0.838617
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df[ df["bathrooms"] == 2 ].describe()
# Out:
#               price          area    bedrooms  bathrooms     stories  \
# count  1.330000e+02    133.000000  133.000000      133.0  133.000000
# mean   6.209206e+06   5699.526316    3.383459        2.0    2.293233
# std    1.916503e+06   1922.549998    0.682262        0.0    1.028252
# min    2.380000e+06   1950.000000    2.000000        2.0    1.000000
# 25%    4.893000e+06   4260.000000    3.000000        2.0    2.000000
# 50%    6.090000e+06   6000.000000    3.000000        2.0    2.000000
# 75%    7.350000e+06   6600.000000    4.000000        2.0    3.000000
# max    1.330000e+07  12090.000000    6.000000        2.0    4.000000
#
#           parking
# count  133.000000
# mean     0.894737
# std      0.863951
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      3.000000

# %%
df[ df["bedrooms"] == 1 ]["price"].min()
# Out:
# 2275000
